# %% [markdown]
# ### Testing `make_factorial`
#
# Tests the `make_factorial` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_factorial
import math

fn = make_factorial()

def test_make_factorial_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_factorial_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_factorial tests passed!")

# %% [markdown]
# ### Testing `compile_factorial`
#
# Tests the `compile_factorial` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_factorial
import math

circuit = compile_factorial(allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_factorial tests passed!")

# %% [markdown]
# ### Testing `make_fibonacci`
#
# Tests the `make_fibonacci` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_fibonacci
import math

fn = make_fibonacci()

def test_make_fibonacci_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_fibonacci_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_fibonacci tests passed!")

# %% [markdown]
# ### Testing `compile_fibonacci`
#
# Tests the `compile_fibonacci` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_fibonacci
import math

circuit = compile_fibonacci(allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_fibonacci tests passed!")

# %% [markdown]
# ### Testing `make_power`
#
# Tests the `make_power` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.
#
# **Aliases**: `make_exponential` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_power
import math

fn = make_power()

def test_make_power_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_power_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_power tests passed!")

# %% [markdown]
# ### Testing `compile_power`
#
# Tests the `compile_power` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.
#
# **Aliases**: `compile_exponential` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_power
import math

circuit = compile_power(allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_power tests passed!")

# %% [markdown]
# ### Testing `make_comb`
#
# Tests the `make_comb` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.
#
# **Aliases**: `make_combinations` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_comb
import math

fn = make_comb(invalid_result=0)

def test_make_comb_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_comb_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_comb tests passed!")

# %% [markdown]
# ### Testing `compile_comb`
#
# Tests the `compile_comb` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.
#
# **Aliases**: `compile_combinations` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_comb
import math

circuit = compile_comb(invalid_result=0, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_comb tests passed!")

# %% [markdown]
# ### Testing `make_perm`
#
# Tests the `make_perm` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.
#
# **Aliases**: `make_permutations` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_perm
import math

fn = make_perm(invalid_result=0)

def test_make_perm_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_perm_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_perm tests passed!")

# %% [markdown]
# ### Testing `compile_perm`
#
# Tests the `compile_perm` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.
#
# **Aliases**: `compile_permutations` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_perm
import math

circuit = compile_perm(invalid_result=0, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_perm tests passed!")

# %% [markdown]
# ### Testing `make_powmod`
#
# Tests the `make_powmod` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_powmod
import math

fn = make_powmod()

def test_make_powmod_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_powmod_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_powmod tests passed!")

# %% [markdown]
# ### Testing `compile_powmod`
#
# Tests the `compile_powmod` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_powmod
import math

circuit = compile_powmod(allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_powmod tests passed!")
