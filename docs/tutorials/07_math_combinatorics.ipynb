# %% [markdown]
# ### Testing `make_factorial`
#
# Tests the `make_factorial` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_factorial
import math

fn = make_factorial(max_n=7)

def test_make_factorial_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_factorial_enc, {'value': 'encrypted'})
inputset = [(0,), (2,), (5,)]
print('Generated Inputs:', inputset)
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_factorial tests passed!")

# %% [markdown]
# ### Testing `compile_factorial`
#
# Tests the `compile_factorial` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_factorial
import math
from concrete_fhe_toolkit.math.combinatorics import make_factorial

circuit = compile_factorial(max_n=7, allow_large_lookup=False)

inputset = [(-7,), (-2,), (-1,), (0,), (3,)]
print('Generated Inputs:', inputset)
for inp in inputset:
    try:
        expected = make_factorial(max_n=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_factorial tests passed!")

# %% [markdown]
# ### Testing `make_fibonacci`
#
# Tests the `make_fibonacci` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_fibonacci
import math

fn = make_fibonacci(max_n=7)

def test_make_fibonacci_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_fibonacci_enc, {'value': 'encrypted'})
inputset = [(-5,), (-2,), (0,), (6,)]
print('Generated Inputs:', inputset)
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_fibonacci tests passed!")

# %% [markdown]
# ### Testing `compile_fibonacci`
#
# Tests the `compile_fibonacci` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_fibonacci
import math
from concrete_fhe_toolkit.math.combinatorics import make_fibonacci

circuit = compile_fibonacci(max_n=7, allow_large_lookup=False)

inputset = [(-4,), (-2,), (0,), (5,)]
print('Generated Inputs:', inputset)
for inp in inputset:
    try:
        expected = make_fibonacci(max_n=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_fibonacci tests passed!")

# %% [markdown]
# ### Testing `make_power`
#
# Tests the `make_power` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.
#
# **Aliases**: `make_exponential` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_power
import math

fn = make_power(base=2, max_exponent=4)

def test_make_power_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_power_enc, {'value': 'encrypted'})
inputset = [(-3,), (-2,), (0,), (2,)]
print('Generated Inputs:', inputset)
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_power tests passed!")

# %% [markdown]
# ### Testing `compile_power`
#
# Tests the `compile_power` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.
#
# **Aliases**: `compile_exponential` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_power
import math
from concrete_fhe_toolkit.math.combinatorics import make_power

circuit = compile_power(base=2, max_exponent=4, allow_large_lookup=False)

inputset = [(-7,), (-3,), (0,), (1,), (4,)]
print('Generated Inputs:', inputset)
for inp in inputset:
    try:
        expected = make_power(base=2, max_exponent=4)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_power tests passed!")

# %% [markdown]
# ### Testing `make_comb`
#
# Tests the `make_comb` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.
#
# **Aliases**: `make_combinations` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_comb
import math

fn = make_comb(max_n=7, invalid_result=7)

def test_make_comb_enc(left, right):
    return fn(left, right)

compiler = fhe.Compiler(test_make_comb_enc, {'left': 'encrypted', 'right': 'encrypted'})
inputset = [(-6, -4), (0, 0), (0, 1), (1, -4), (4, -1)]
print('Generated Inputs:', inputset)
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_comb tests passed!")

# %% [markdown]
# ### Testing `compile_comb`
#
# Tests the `compile_comb` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.
#
# **Aliases**: `compile_combinations` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_comb
import math
from concrete_fhe_toolkit.math.combinatorics import make_comb

circuit = compile_comb(max_n=7, invalid_result=7, allow_large_lookup=False)

inputset = [(0, 0), (3, 4), (4, 0), (5, -4)]
print('Generated Inputs:', inputset)
for inp in inputset:
    try:
        expected = make_comb(max_n=7, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_comb tests passed!")

# %% [markdown]
# ### Testing `make_perm`
#
# Tests the `make_perm` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.
#
# **Aliases**: `make_permutations` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_perm
import math

fn = make_perm(max_n=7, invalid_result=7)

def test_make_perm_enc(left, right):
    return fn(left, right)

compiler = fhe.Compiler(test_make_perm_enc, {'left': 'encrypted', 'right': 'encrypted'})
inputset = [(-6, -3), (-4, -1), (0, 0), (4, -4), (5, -7)]
print('Generated Inputs:', inputset)
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_perm tests passed!")

# %% [markdown]
# ### Testing `compile_perm`
#
# Tests the `compile_perm` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.
#
# **Aliases**: `compile_permutations` can also be used equivalently.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_perm
import math
from concrete_fhe_toolkit.math.combinatorics import make_perm

circuit = compile_perm(max_n=7, invalid_result=7, allow_large_lookup=False)

inputset = [(-3, 3), (0, 0), (0, 1), (1, -2), (2, -2)]
print('Generated Inputs:', inputset)
for inp in inputset:
    try:
        expected = make_perm(max_n=7, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_perm tests passed!")

# %% [markdown]
# ### Testing `make_powmod`
#
# Tests the `make_powmod` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import make_powmod
import math

fn = make_powmod(base=2, modulus=5, max_exponent=4)

def test_make_powmod_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_powmod_enc, {'value': 'encrypted'})
inputset = [(-2,), (-1,), (0,), (1,), (4,)]
print('Generated Inputs:', inputset)
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_powmod tests passed!")

# %% [markdown]
# ### Testing `compile_powmod`
#
# Tests the `compile_powmod` function. Includes a robust set of generated test cases designed to test boundaries and edge cases.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.combinatorics import compile_powmod
import math
from concrete_fhe_toolkit.math.combinatorics import make_powmod

circuit = compile_powmod(base=2, modulus=5, max_exponent=4, allow_large_lookup=False)

inputset = [(-3,), (-2,), (0,), (4,)]
print('Generated Inputs:', inputset)
for inp in inputset:
    try:
        expected = make_powmod(base=2, modulus=5, max_exponent=4)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_powmod tests passed!")
