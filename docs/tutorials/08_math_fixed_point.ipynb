# %% [markdown]
# ### Testing `make_floor`
#
# Tests the `make_floor` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_floor

fn = make_floor(min_input=-3, max_input=3, scale=10)

def test_make_floor_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_floor_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_floor tests passed!")

# %% [markdown]
# ### Testing `compile_floor`
#
# Tests the `compile_floor` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_floor

circuit = compile_floor(min_input=-3, max_input=3, scale=10, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_floor tests passed!")

# %% [markdown]
# ### Testing `make_ceil`
#
# Tests the `make_ceil` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_ceil

fn = make_ceil(min_input=-3, max_input=3, scale=10)

def test_make_ceil_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_ceil_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_ceil tests passed!")

# %% [markdown]
# ### Testing `compile_ceil`
#
# Tests the `compile_ceil` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_ceil

circuit = compile_ceil(min_input=-3, max_input=3, scale=10, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_ceil tests passed!")

# %% [markdown]
# ### Testing `make_trunc`
#
# Tests the `make_trunc` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_trunc

fn = make_trunc(min_input=-3, max_input=3, scale=10)

def test_make_trunc_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_trunc_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_trunc tests passed!")

# %% [markdown]
# ### Testing `compile_trunc`
#
# Tests the `compile_trunc` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_trunc

circuit = compile_trunc(min_input=-3, max_input=3, scale=10, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_trunc tests passed!")

# %% [markdown]
# ### Testing `make_round`
#
# Tests the `make_round` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_round

fn = make_round(min_input=-3, max_input=3, scale=10)

def test_make_round_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_round_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_round tests passed!")

# %% [markdown]
# ### Testing `compile_round`
#
# Tests the `compile_round` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_round

circuit = compile_round(min_input=-3, max_input=3, scale=10, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_round tests passed!")

# %% [markdown]
# ### Testing `make_floor_ceil`
#
# Tests the `make_floor_ceil` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_floor_ceil

fn = make_floor_ceil(min_input=-3, max_input=3, scale=10)

def test_make_floor_ceil_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_floor_ceil_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_floor_ceil tests passed!")

# %% [markdown]
# ### Testing `compile_floor_ceil`
#
# Tests the `compile_floor_ceil` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_floor_ceil

circuit = compile_floor_ceil(min_input=-3, max_input=3, scale=10, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_floor_ceil tests passed!")

# %% [markdown]
# ### Testing `make_rescale`
#
# Tests the `make_rescale` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_rescale

fn = make_rescale(min_input=-3, max_input=3, rounding=nearest)

def test_make_rescale_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_rescale_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_rescale tests passed!")

# %% [markdown]
# ### Testing `compile_rescale`
#
# Tests the `compile_rescale` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_rescale

circuit = compile_rescale(min_input=-3, max_input=3, input_scale=10, output_scale=10, rounding=nearest, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_rescale tests passed!")

# %% [markdown]
# ### Testing `make_round_to_multiple`
#
# Tests the `make_round_to_multiple` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_round_to_multiple

fn = make_round_to_multiple(min_input=-3, max_input=3, rounding=nearest)

def test_make_round_to_multiple_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_round_to_multiple_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_round_to_multiple tests passed!")

# %% [markdown]
# ### Testing `compile_round_to_multiple`
#
# Tests the `compile_round_to_multiple` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_round_to_multiple

circuit = compile_round_to_multiple(min_input=-3, max_input=3, rounding=nearest, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_round_to_multiple tests passed!")

# %% [markdown]
# ### Testing `make_modf`
#
# Tests the `make_modf` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_modf

fn = make_modf(min_input=-3, max_input=3, scale=10)

def test_make_modf_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_modf_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_modf tests passed!")

# %% [markdown]
# ### Testing `compile_modf`
#
# Tests the `compile_modf` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_modf

circuit = compile_modf(min_input=-3, max_input=3, scale=10, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_modf tests passed!")

# %% [markdown]
# ### Testing `make_fixed_point_multiply`
#
# Tests the `make_fixed_point_multiply` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import make_fixed_point_multiply

fn = make_fixed_point_multiply(scale=10, rounding=floor)

def test_make_fixed_point_multiply_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_fixed_point_multiply_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_fixed_point_multiply tests passed!")

# %% [markdown]
# ### Testing `compile_fixed_point_multiply`
#
# Tests the `compile_fixed_point_multiply` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import compile_fixed_point_multiply

circuit = compile_fixed_point_multiply(min_input=-3, max_input=3, scale=10, rounding=floor)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_fixed_point_multiply tests passed!")

# %% [markdown]
# ### Testing `encode_fixed_point`
#
# Tests the `encode_fixed_point` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import encode_fixed_point

def test_encode_fixed_point(value, scale):
    return encode_fixed_point(value, scale)

compiler = fhe.Compiler(test_encode_fixed_point, {'value': 'encrypted', 'scale': 'encrypted'})
inputset = [(2, 1), (-1, -1), (0, 0), (3, -2), (0, 2)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = encode_fixed_point(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("encode_fixed_point tests passed!")

# %% [markdown]
# ### Testing `decode_fixed_point`
#
# Tests the `decode_fixed_point` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.fixed_point import decode_fixed_point

def test_decode_fixed_point(value, scale):
    return decode_fixed_point(value, scale)

compiler = fhe.Compiler(test_decode_fixed_point, {'value': 'encrypted', 'scale': 'encrypted'})
inputset = [(2, 1), (-1, -1), (0, 0), (3, -2), (0, 2)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = decode_fixed_point(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("decode_fixed_point tests passed!")
