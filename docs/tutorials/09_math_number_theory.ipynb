# %% [markdown]
# ### Testing `make_gcd`
#
# Tests the `make_gcd` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_gcd
import math

fn = make_gcd(min_value=-3, max_value=3)

def test_make_gcd_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_gcd_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_gcd tests passed!")

# %% [markdown]
# ### Testing `compile_gcd`
#
# Tests the `compile_gcd` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_gcd
import math

circuit = compile_gcd(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_gcd tests passed!")

# %% [markdown]
# ### Testing `make_lcm`
#
# Tests the `make_lcm` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_lcm
import math

fn = make_lcm(min_value=-3, max_value=3)

def test_make_lcm_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_lcm_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_lcm tests passed!")

# %% [markdown]
# ### Testing `compile_lcm`
#
# Tests the `compile_lcm` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_lcm
import math

circuit = compile_lcm(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_lcm tests passed!")

# %% [markdown]
# ### Testing `make_is_coprime`
#
# Tests the `make_is_coprime` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_is_coprime
import math

fn = make_is_coprime(min_value=-3, max_value=3)

def test_make_is_coprime_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_is_coprime_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_is_coprime tests passed!")

# %% [markdown]
# ### Testing `compile_is_coprime`
#
# Tests the `compile_is_coprime` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_is_coprime
import math

circuit = compile_is_coprime(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_is_coprime tests passed!")

# %% [markdown]
# ### Testing `make_is_divisible`
#
# Tests the `make_is_divisible` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_is_divisible
import math

fn = make_is_divisible(min_numerator=-3, max_numerator=3, min_denominator=-3, max_denominator=3, zero_result=7)

def test_make_is_divisible_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_is_divisible_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_is_divisible tests passed!")

# %% [markdown]
# ### Testing `compile_is_divisible`
#
# Tests the `compile_is_divisible` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_is_divisible
import math

circuit = compile_is_divisible(min_numerator=-3, max_numerator=3, min_denominator=-3, max_denominator=3, zero_result=7, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_is_divisible tests passed!")

# %% [markdown]
# ### Testing `make_isqrt`
#
# Tests the `make_isqrt` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_isqrt
import math

fn = make_isqrt(max_value=3)

def test_make_isqrt_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_isqrt_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_isqrt tests passed!")

# %% [markdown]
# ### Testing `compile_isqrt`
#
# Tests the `compile_isqrt` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_isqrt
import math

circuit = compile_isqrt(max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_isqrt tests passed!")

# %% [markdown]
# ### Testing `make_is_even`
#
# Tests the `make_is_even` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_is_even
import math

fn = make_is_even(min_value=-3, max_value=3)

def test_make_is_even_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_is_even_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_is_even tests passed!")

# %% [markdown]
# ### Testing `compile_is_even`
#
# Tests the `compile_is_even` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_is_even
import math

circuit = compile_is_even(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_is_even tests passed!")

# %% [markdown]
# ### Testing `make_is_odd`
#
# Tests the `make_is_odd` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_is_odd
import math

fn = make_is_odd(min_value=-3, max_value=3)

def test_make_is_odd_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_is_odd_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_is_odd tests passed!")

# %% [markdown]
# ### Testing `compile_is_odd`
#
# Tests the `compile_is_odd` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_is_odd
import math

circuit = compile_is_odd(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_is_odd tests passed!")

# %% [markdown]
# ### Testing `make_is_prime`
#
# Tests the `make_is_prime` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_is_prime
import math

fn = make_is_prime(min_value=-3, max_value=3)

def test_make_is_prime_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_is_prime_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_is_prime tests passed!")

# %% [markdown]
# ### Testing `compile_is_prime`
#
# Tests the `compile_is_prime` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_is_prime
import math

circuit = compile_is_prime(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_is_prime tests passed!")

# %% [markdown]
# ### Testing `make_totient`
#
# Tests the `make_totient` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_totient
import math

fn = make_totient(min_value=-3, max_value=3)

def test_make_totient_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_totient_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_totient tests passed!")

# %% [markdown]
# ### Testing `compile_totient`
#
# Tests the `compile_totient` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_totient
import math

circuit = compile_totient(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_totient tests passed!")

# %% [markdown]
# ### Testing `make_next_prime`
#
# Tests the `make_next_prime` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_next_prime
import math

fn = make_next_prime(min_value=-3, max_value=3)

def test_make_next_prime_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_next_prime_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_next_prime tests passed!")

# %% [markdown]
# ### Testing `compile_next_prime`
#
# Tests the `compile_next_prime` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_next_prime
import math

circuit = compile_next_prime(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_next_prime tests passed!")

# %% [markdown]
# ### Testing `make_mod_inverse`
#
# Tests the `make_mod_inverse` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_mod_inverse
import math

fn = make_mod_inverse(min_value=-3, max_value=3, invalid_result=0)

def test_make_mod_inverse_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_mod_inverse_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_mod_inverse tests passed!")

# %% [markdown]
# ### Testing `compile_mod_inverse`
#
# Tests the `compile_mod_inverse` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_mod_inverse
import math

circuit = compile_mod_inverse(min_value=-3, max_value=3, invalid_result=0, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_mod_inverse tests passed!")

# %% [markdown]
# ### Testing `make_hypot`
#
# Tests the `make_hypot` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_hypot
import math

fn = make_hypot(min_value=-3, max_value=3)

def test_make_hypot_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_hypot_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_hypot tests passed!")

# %% [markdown]
# ### Testing `compile_hypot`
#
# Tests the `compile_hypot` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_hypot
import math

circuit = compile_hypot(min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_hypot tests passed!")

# %% [markdown]
# ### Testing `make_ilogb`
#
# Tests the `make_ilogb` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_ilogb
import math

fn = make_ilogb(min_value=-3, max_value=3, invalid_result=0)

def test_make_ilogb_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_ilogb_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_ilogb tests passed!")

# %% [markdown]
# ### Testing `compile_ilogb`
#
# Tests the `compile_ilogb` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_ilogb
import math

circuit = compile_ilogb(min_value=-3, max_value=3, invalid_result=0, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_ilogb tests passed!")

# %% [markdown]
# ### Testing `make_dist`
#
# Tests the `make_dist` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_dist
import math

fn = make_dist(size=3, min_value=-3, max_value=3)

def test_make_dist_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_dist_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_dist tests passed!")

# %% [markdown]
# ### Testing `compile_dist`
#
# Tests the `compile_dist` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_dist
import math

circuit = compile_dist(size=3, min_value=-3, max_value=3, allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_dist tests passed!")

# %% [markdown]
# ### Testing `make_pow`
#
# Tests the `make_pow` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import make_pow
import math

fn = make_pow()

def test_make_pow_enc(arg0):
    return fn(arg0)

compiler = fhe.Compiler(test_make_pow_enc, {'arg0': 'encrypted'})
inputset = [(2,), (-1,), (0,), (3,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_pow tests passed!")

# %% [markdown]
# ### Testing `compile_pow`
#
# Tests the `compile_pow` function. Includes various inputs to cover edge cases like positives, negatives, and zeros.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.number_theory import compile_pow
import math

circuit = compile_pow(allow_large_lookup=False)

inputset = [(2,), (-1,), (0,), (3,)]
for inp in inputset:
    try:
        circuit.encrypt_run_decrypt(*inp)
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_pow tests passed!")
