# %% [markdown]
# ### Testing `make_sin`
#
# Tests the `make_sin` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_sin
import math

fn = make_sin(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees)

def test_make_sin_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_sin_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_sin tests passed!")

# %% [markdown]
# ### Testing `compile_sin`
#
# Tests the `compile_sin` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_sin
import math
from concrete_fhe_toolkit.math.special import make_sin

circuit = compile_sin(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_sin(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_sin tests passed!")

# %% [markdown]
# ### Testing `make_cos`
#
# Tests the `make_cos` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_cos
import math

fn = make_cos(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees)

def test_make_cos_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_cos_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_cos tests passed!")

# %% [markdown]
# ### Testing `compile_cos`
#
# Tests the `compile_cos` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_cos
import math
from concrete_fhe_toolkit.math.special import make_cos

circuit = compile_cos(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_cos(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_cos tests passed!")

# %% [markdown]
# ### Testing `make_tan`
#
# Tests the `make_tan` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_tan
import math

fn = make_tan(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees)

def test_make_tan_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_tan_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_tan tests passed!")

# %% [markdown]
# ### Testing `compile_tan`
#
# Tests the `compile_tan` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_tan
import math
from concrete_fhe_toolkit.math.special import make_tan

circuit = compile_tan(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_tan(min_input=-15, max_input=15, input_scale=10, output_scale=10, angle_unit=degrees)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_tan tests passed!")

# %% [markdown]
# ### Testing `make_exp`
#
# Tests the `make_exp` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_exp
import math

fn = make_exp(min_input=0, max_input=15, input_scale=10, output_scale=10)

def test_make_exp_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_exp_enc, {'value': 'encrypted'})
inputset = [(1,), (2,), (5,), (10,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_exp tests passed!")

# %% [markdown]
# ### Testing `compile_exp`
#
# Tests the `compile_exp` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_exp
import math
from concrete_fhe_toolkit.math.special import make_exp

circuit = compile_exp(min_input=0, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(1,), (2,), (5,), (10,)]
for inp in inputset:
    try:
        expected = make_exp(min_input=0, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_exp tests passed!")

# %% [markdown]
# ### Testing `make_expm1`
#
# Tests the `make_expm1` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_expm1
import math

fn = make_expm1(min_input=0, max_input=15, input_scale=10, output_scale=10)

def test_make_expm1_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_expm1_enc, {'value': 'encrypted'})
inputset = [(1,), (2,), (5,), (10,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_expm1 tests passed!")

# %% [markdown]
# ### Testing `compile_expm1`
#
# Tests the `compile_expm1` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_expm1
import math
from concrete_fhe_toolkit.math.special import make_expm1

circuit = compile_expm1(min_input=0, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(1,), (2,), (5,), (10,)]
for inp in inputset:
    try:
        expected = make_expm1(min_input=0, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_expm1 tests passed!")

# %% [markdown]
# ### Testing `make_log`
#
# Tests the `make_log` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_log
import math

fn = make_log(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7, base=2)

def test_make_log_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_log_enc, {'value': 'encrypted'})
inputset = [(1,), (2,), (5,), (10,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_log tests passed!")

# %% [markdown]
# ### Testing `compile_log`
#
# Tests the `compile_log` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_log
import math
from concrete_fhe_toolkit.math.special import make_log

circuit = compile_log(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7, base=2, allow_large_lookup=False)

inputset = [(1,), (2,), (5,), (10,)]
for inp in inputset:
    try:
        expected = make_log(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7, base=2)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_log tests passed!")

# %% [markdown]
# ### Testing `make_log2`
#
# Tests the `make_log2` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_log2
import math

fn = make_log2(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_log2_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_log2_enc, {'value': 'encrypted'})
inputset = [(1,), (2,), (5,), (10,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_log2 tests passed!")

# %% [markdown]
# ### Testing `compile_log2`
#
# Tests the `compile_log2` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_log2
import math
from concrete_fhe_toolkit.math.special import make_log2

circuit = compile_log2(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(1,), (2,), (5,), (10,)]
for inp in inputset:
    try:
        expected = make_log2(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_log2 tests passed!")

# %% [markdown]
# ### Testing `make_log10`
#
# Tests the `make_log10` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_log10
import math

fn = make_log10(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_log10_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_log10_enc, {'value': 'encrypted'})
inputset = [(1,), (2,), (5,), (10,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_log10 tests passed!")

# %% [markdown]
# ### Testing `compile_log10`
#
# Tests the `compile_log10` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_log10
import math
from concrete_fhe_toolkit.math.special import make_log10

circuit = compile_log10(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(1,), (2,), (5,), (10,)]
for inp in inputset:
    try:
        expected = make_log10(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_log10 tests passed!")

# %% [markdown]
# ### Testing `make_log1p`
#
# Tests the `make_log1p` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_log1p
import math

fn = make_log1p(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_log1p_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_log1p_enc, {'value': 'encrypted'})
inputset = [(1,), (2,), (5,), (10,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_log1p tests passed!")

# %% [markdown]
# ### Testing `compile_log1p`
#
# Tests the `compile_log1p` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_log1p
import math
from concrete_fhe_toolkit.math.special import make_log1p

circuit = compile_log1p(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(1,), (2,), (5,), (10,)]
for inp in inputset:
    try:
        expected = make_log1p(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_log1p tests passed!")

# %% [markdown]
# ### Testing `make_sqrt`
#
# Tests the `make_sqrt` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_sqrt
import math

fn = make_sqrt(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_sqrt_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_sqrt_enc, {'value': 'encrypted'})
inputset = [(0,), (1,), (4,), (9,), (15,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_sqrt tests passed!")

# %% [markdown]
# ### Testing `compile_sqrt`
#
# Tests the `compile_sqrt` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_sqrt
import math
from concrete_fhe_toolkit.math.special import make_sqrt

circuit = compile_sqrt(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(0,), (1,), (4,), (9,), (15,)]
for inp in inputset:
    try:
        expected = make_sqrt(min_input=0, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_sqrt tests passed!")

# %% [markdown]
# ### Testing `make_erf`
#
# Tests the `make_erf` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_erf
import math

fn = make_erf(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_erf_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_erf_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_erf tests passed!")

# %% [markdown]
# ### Testing `compile_erf`
#
# Tests the `compile_erf` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_erf
import math
from concrete_fhe_toolkit.math.special import make_erf

circuit = compile_erf(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_erf(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_erf tests passed!")

# %% [markdown]
# ### Testing `make_erfc`
#
# Tests the `make_erfc` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_erfc
import math

fn = make_erfc(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_erfc_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_erfc_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_erfc tests passed!")

# %% [markdown]
# ### Testing `compile_erfc`
#
# Tests the `compile_erfc` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_erfc
import math
from concrete_fhe_toolkit.math.special import make_erfc

circuit = compile_erfc(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_erfc(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_erfc tests passed!")

# %% [markdown]
# ### Testing `make_tanh`
#
# Tests the `make_tanh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_tanh
import math

fn = make_tanh(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_tanh_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_tanh_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_tanh tests passed!")

# %% [markdown]
# ### Testing `compile_tanh`
#
# Tests the `compile_tanh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_tanh
import math
from concrete_fhe_toolkit.math.special import make_tanh

circuit = compile_tanh(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_tanh(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_tanh tests passed!")

# %% [markdown]
# ### Testing `make_sinh`
#
# Tests the `make_sinh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_sinh
import math

fn = make_sinh(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_sinh_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_sinh_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_sinh tests passed!")

# %% [markdown]
# ### Testing `compile_sinh`
#
# Tests the `compile_sinh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_sinh
import math
from concrete_fhe_toolkit.math.special import make_sinh

circuit = compile_sinh(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_sinh(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_sinh tests passed!")

# %% [markdown]
# ### Testing `make_cosh`
#
# Tests the `make_cosh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_cosh
import math

fn = make_cosh(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_cosh_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_cosh_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_cosh tests passed!")

# %% [markdown]
# ### Testing `compile_cosh`
#
# Tests the `compile_cosh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_cosh
import math
from concrete_fhe_toolkit.math.special import make_cosh

circuit = compile_cosh(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_cosh(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_cosh tests passed!")

# %% [markdown]
# ### Testing `make_sigmoid`
#
# Tests the `make_sigmoid` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_sigmoid
import math

fn = make_sigmoid(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_sigmoid_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_sigmoid_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_sigmoid tests passed!")

# %% [markdown]
# ### Testing `compile_sigmoid`
#
# Tests the `compile_sigmoid` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_sigmoid
import math
from concrete_fhe_toolkit.math.special import make_sigmoid

circuit = compile_sigmoid(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_sigmoid(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_sigmoid tests passed!")

# %% [markdown]
# ### Testing `make_asin`
#
# Tests the `make_asin` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_asin
import math

fn = make_asin(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_asin_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_asin_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_asin tests passed!")

# %% [markdown]
# ### Testing `compile_asin`
#
# Tests the `compile_asin` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_asin
import math
from concrete_fhe_toolkit.math.special import make_asin

circuit = compile_asin(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_asin(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_asin tests passed!")

# %% [markdown]
# ### Testing `make_acos`
#
# Tests the `make_acos` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_acos
import math

fn = make_acos(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_acos_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_acos_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_acos tests passed!")

# %% [markdown]
# ### Testing `compile_acos`
#
# Tests the `compile_acos` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_acos
import math
from concrete_fhe_toolkit.math.special import make_acos

circuit = compile_acos(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_acos(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_acos tests passed!")

# %% [markdown]
# ### Testing `make_atan`
#
# Tests the `make_atan` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_atan
import math

fn = make_atan(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_atan_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_atan_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_atan tests passed!")

# %% [markdown]
# ### Testing `compile_atan`
#
# Tests the `compile_atan` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_atan
import math
from concrete_fhe_toolkit.math.special import make_atan

circuit = compile_atan(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_atan(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_atan tests passed!")

# %% [markdown]
# ### Testing `make_cbrt`
#
# Tests the `make_cbrt` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_cbrt
import math

fn = make_cbrt(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_cbrt_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_cbrt_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_cbrt tests passed!")

# %% [markdown]
# ### Testing `compile_cbrt`
#
# Tests the `compile_cbrt` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_cbrt
import math
from concrete_fhe_toolkit.math.special import make_cbrt

circuit = compile_cbrt(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_cbrt(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_cbrt tests passed!")

# %% [markdown]
# ### Testing `make_degrees`
#
# Tests the `make_degrees` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_degrees
import math

fn = make_degrees(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_degrees_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_degrees_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_degrees tests passed!")

# %% [markdown]
# ### Testing `compile_degrees`
#
# Tests the `compile_degrees` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_degrees
import math
from concrete_fhe_toolkit.math.special import make_degrees

circuit = compile_degrees(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_degrees(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_degrees tests passed!")

# %% [markdown]
# ### Testing `make_radians`
#
# Tests the `make_radians` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_radians
import math

fn = make_radians(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_radians_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_radians_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_radians tests passed!")

# %% [markdown]
# ### Testing `compile_radians`
#
# Tests the `compile_radians` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_radians
import math
from concrete_fhe_toolkit.math.special import make_radians

circuit = compile_radians(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_radians(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_radians tests passed!")

# %% [markdown]
# ### Testing `make_gamma`
#
# Tests the `make_gamma` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_gamma
import math

fn = make_gamma(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_gamma_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_gamma_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_gamma tests passed!")

# %% [markdown]
# ### Testing `compile_gamma`
#
# Tests the `compile_gamma` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_gamma
import math
from concrete_fhe_toolkit.math.special import make_gamma

circuit = compile_gamma(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_gamma(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_gamma tests passed!")

# %% [markdown]
# ### Testing `make_lgamma`
#
# Tests the `make_lgamma` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_lgamma
import math

fn = make_lgamma(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_lgamma_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_lgamma_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_lgamma tests passed!")

# %% [markdown]
# ### Testing `compile_lgamma`
#
# Tests the `compile_lgamma` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_lgamma
import math
from concrete_fhe_toolkit.math.special import make_lgamma

circuit = compile_lgamma(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_lgamma(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_lgamma tests passed!")

# %% [markdown]
# ### Testing `make_atan2`
#
# Tests the `make_atan2` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_atan2
import math

fn = make_atan2(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_atan2_enc(left, right):
    return fn(left, right)

compiler = fhe.Compiler(test_make_atan2_enc, {'left': 'encrypted', 'right': 'encrypted'})
inputset = [(15, 1), (-15, -2), (0, 0), (14, -7), (0, 15)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_atan2 tests passed!")

# %% [markdown]
# ### Testing `compile_atan2`
#
# Tests the `compile_atan2` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_atan2
import math
from concrete_fhe_toolkit.math.special import make_atan2

circuit = compile_atan2(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15, 1), (-15, -2), (0, 0), (14, -7), (0, 15)]
for inp in inputset:
    try:
        expected = make_atan2(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_atan2 tests passed!")

# %% [markdown]
# ### Testing `make_asinh`
#
# Tests the `make_asinh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_asinh
import math

fn = make_asinh(min_input=-15, max_input=15, input_scale=10, output_scale=10)

def test_make_asinh_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_asinh_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_asinh tests passed!")

# %% [markdown]
# ### Testing `compile_asinh`
#
# Tests the `compile_asinh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_asinh
import math
from concrete_fhe_toolkit.math.special import make_asinh

circuit = compile_asinh(min_input=-15, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_asinh(min_input=-15, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_asinh tests passed!")

# %% [markdown]
# ### Testing `make_acosh`
#
# Tests the `make_acosh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_acosh
import math

fn = make_acosh(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_acosh_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_acosh_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_acosh tests passed!")

# %% [markdown]
# ### Testing `compile_acosh`
#
# Tests the `compile_acosh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_acosh
import math
from concrete_fhe_toolkit.math.special import make_acosh

circuit = compile_acosh(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_acosh(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_acosh tests passed!")

# %% [markdown]
# ### Testing `make_atanh`
#
# Tests the `make_atanh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_atanh
import math

fn = make_atanh(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)

def test_make_atanh_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_atanh_enc, {'value': 'encrypted'})
inputset = [(15,), (-15,), (0,), (2,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_atanh tests passed!")

# %% [markdown]
# ### Testing `compile_atanh`
#
# Tests the `compile_atanh` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_atanh
import math
from concrete_fhe_toolkit.math.special import make_atanh

circuit = compile_atanh(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7, allow_large_lookup=False)

inputset = [(15,), (-15,), (0,), (2,)]
for inp in inputset:
    try:
        expected = make_atanh(min_input=-15, max_input=15, input_scale=10, output_scale=10, invalid_result=7)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_atanh tests passed!")

# %% [markdown]
# ### Testing `make_exp2`
#
# Tests the `make_exp2` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import make_exp2
import math

fn = make_exp2(min_input=0, max_input=15, input_scale=10, output_scale=10)

def test_make_exp2_enc(value):
    return fn(value)

compiler = fhe.Compiler(test_make_exp2_enc, {'value': 'encrypted'})
inputset = [(1,), (2,), (5,), (10,)]
circuit = compiler.compile(inputset)

for inp in inputset:
    try:
        expected = fn(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("make_exp2 tests passed!")

# %% [markdown]
# ### Testing `compile_exp2`
#
# Tests the `compile_exp2` function. Includes specific edge cases and a widened `[-15, 15]` input domain.

# %%
from concrete import fhe
from concrete_fhe_toolkit.math.special import compile_exp2
import math
from concrete_fhe_toolkit.math.special import make_exp2

circuit = compile_exp2(min_input=0, max_input=15, input_scale=10, output_scale=10, allow_large_lookup=False)

inputset = [(1,), (2,), (5,), (10,)]
for inp in inputset:
    try:
        expected = make_exp2(min_input=0, max_input=15, input_scale=10, output_scale=10)(*inp)
        if isinstance(expected, tuple):
            assert tuple(int(x) for x in circuit.encrypt_run_decrypt(*inp)) == expected, f"Failed at {inp}"
        else:
            assert int(circuit.encrypt_run_decrypt(*inp)) == int(expected), f"Failed at {inp}"
    except Exception as e:
        print(f"Skipping {inp} due to bounds or other error: {e}")

print("compile_exp2 tests passed!")
