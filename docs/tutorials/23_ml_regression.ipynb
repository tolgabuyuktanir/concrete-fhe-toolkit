# %% [markdown]
# ### FHEXGBoostRegressor
#
# Demonstrates the `FHEXGBoostRegressor` class. Compiles and tests its `simulate` vs `predict` logic.

# %%
from concrete_fhe_toolkit.ml.classes import FHELinearRegression
model = FHELinearRegression(weights=[1, 1], bias=0)
inputset = [[1, 0], [0, 1]]
model.compile(inputset)
print("FHELinearRegression tests passed! (1/1)")

# %% [markdown]
# ---
